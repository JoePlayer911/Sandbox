# %%
'''
Group Assignment #1
Nama Group : Swift
Ketua : Juan Christian Chandra (212100108)
Anggota :
1. Gilbert Kurniawan (212100157)
2. Vincent Waiman (212100113)
'''
import random
import time

print("Welcome to Snakes and Ladders Game.\n",
      "How to play:\n",
      "1. Each player puts their token next to the game board near the “1” square.\n",
      "2. Roll a single die on your turn.\n", 
      "3. Move your token forward the number of spaces shown on the die.\n",
      "4. If your token lands at the bottom of a ladder, you will move up to the top of the ladder.\n",
      "5. If your token lands on the head of a snake, you must slide down to the bottom of the snake.\n",
      "6. The first player to get to the “25” square wins.\n")

def checkSquare(pos, orig, dest):
  print(pos, end=" -> ")
  pos = 0 
  if (dest > orig):
    print("You hit a ladder", end=" -> moved to ")
  else :
    print("You hit a snake", end=" -> moved to ")
  return dest
    
def tossDie (pName, pos):
  time.sleep(loading_time)
  die = random.randint(1, 12) 
  print("You got", die)
  print(f"{pName} moved from {pos} to", end=" ") 
  pos = pos + die

  if (pos == 5):
    pos = checkSquare (pos, 5, 15)
  elif (pos == 9):
    pos = checkSquare (pos, 9, 4)
  elif (pos == 12):
    pos = checkSquare (pos, 12, 21)
  elif (pos == 24):
    pos = checkSquare (pos, 24, 13)
  
  if (pos > 100):
    pos = ((pos - 100)-100)*-1
  
  if (pos == 100):
    print(pos, "(WINNER)")
  else:
    print(pos)
  return pos

name1 = input("Please enter the name of the first player  : ")
name2 = input("Please enter the name of the second player : ")
name3 = input("Please enter the name of the third player  : ")
loading_time = 1
round = 1
player1 = player2 = player3 = 0
while(True):
  print("\nRound", round)
  round = round + 1
  player1_turn = input(name1 + "'s turn, press enter to roll dice: ")
  print("Rolling dice...")
  player1 = tossDie (name1, player1)
  if (player1 == 100):
    break
  player2_turn = input("\n" + name2 + "'s turn, press enter to roll dice: ")
  print("Rolling dice...")
  player2 = tossDie (name2, player2)
  if (player2 == 100):
    break
  player3_turn = input("\n" + name3 + "'s turn, press enter to roll dice: ")
  print("Rolling dice...")    
  player3 = tossDie (name3, player3)
  if (player3 == 100):
    break
print("\nThank you for playing!")
# Out:
# Welcome to Snakes and Ladders Game.
#  How to play:
#  1. Each player puts their token next to the game board near the “1” square.
#  2. Roll a single die on your turn.
#  3. Move your token forward the number of spaces shown on the die.
#  4. If your token lands at the bottom of a ladder, you will move up to the top of the ladder.
#  5. If your token lands on the head of a snake, you must slide down to the bottom of the snake.
#  6. The first player to get to the “25” square wins.
#
# Please enter the name of the first player  : Jonathan
# Please enter the name of the second player : Nicholas
# Please enter the name of the third player  : Senjaya
#
# Round 1
# Jonathan's turn, press enter to roll dice:
# Rolling dice...
# You got 9
# Jonathan moved from 0 to 9 -> You hit a snake -> moved to 4
#
# Nicholas's turn, press enter to roll dice:
# Rolling dice...
# You got 9
# Nicholas moved from 0 to 9 -> You hit a snake -> moved to 4
#
# Senjaya's turn, press enter to roll dice:
# ...

# %%
a, b, c, d=map(int,(input().split()))
remainder1 =(600 - (b15))
remainder2 =(remainder1 - (c20))
remainder3 =(remainder2 - (d30))
remainder4 =(remainder3)
print(f"Checking here: {remainder4}")
coin50 = (remainder4/50)
coin5 = (remainder4-(coin5050)/5)
coin1 = ((coin5*5)/1)
print(f"{coin1:.0f}")
print(f"{coin5:.0f}")
print(f"{coin50:.0f}")
# Out:
# 600 1 2 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-083c1b1d985f> in <module>()
#       1 a, b, c, d=map(int,(input().split()))
# ----> 2 remainder1 =(600 - (b15))
#       3 remainder2 =(remainder1 - (c20))
#       4 remainder3 =(remainder2 - (d30))
#       5 remainder4 =(remainder3)
#
# NameError: name 'b15' is not defined
