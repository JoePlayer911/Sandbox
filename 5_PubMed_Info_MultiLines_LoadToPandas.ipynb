# %%
# 2020/10/15 Jing-Doo Wang 
# jdwang@asia.edu.tw
# PubMed Articles Preprosess

# %%
CancerTypeArticles = [
"/content/Output_MultiLines/pubmed-lungcancer-set_Output.xlsx",
"/content/Output_MultiLines/pubmed-Breastcanc-set_Output.xlsx",
"/content/Output_MultiLines/pubmed-Colorectal-set_Output.xlsx",
]
CancerTypeArticles
# Out:
# ['/content/Output_MultiLines/pubmed-lungcancer-set_Output.xlsx',
#  '/content/Output_MultiLines/pubmed-Breastcanc-set_Output.xlsx',
#  '/content/Output_MultiLines/pubmed-Colorectal-set_Output.xlsx']

# %%
import pandas as pd

PubMed_Articles = pd.read_excel(CancerTypeArticles[0])
PubMed_Articles.head(5)
# Out:
#    Unnamed: 0     PUMID                                                 TI  \
# 0           0  27261907                       Epidemiology of Lung Cancer.
# 1           1  27535388  Diagnosis and Molecular Classification of Lung...
# 2           2  29635240                      Heterogeneity in Lung Cancer.
#
#                                                   AB  Type
# 0  Lung cancer has been transformed from a rare d...  Lung
# 1  Lung cancer is a complex disease composed of d...  Lung
# 2  Lung cancer diagnosis is a challenge since it ...  Lung

# %%
PubMed_Articles['Type'].unique()
# Out:
# array(['Lung'], dtype=object)

# %%
# 
# pandas.DataFrame.merge https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html
# Merge, join, concatenate and compare https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
import pandas as pd

PubMed_Articles = pd.read_excel(CancerTypeArticles[0])
#PubMed_Articles
for i in range (1,len(CancerTypeArticles)):
    print(CancerTypeArticles[i])
    OnePubMed_Articles = pd.read_excel(CancerTypeArticles[i])
    PubMed_Articles = PubMed_Articles.append(OnePubMed_Articles)
# Out:
# /content/Output_MultiLines/pubmed-Breastcanc-set_Output.xlsx
# /content/Output_MultiLines/pubmed-Colorectal-set_Output.xlsx
# <ipython-input-9-8b13acba0f32>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   PubMed_Articles = PubMed_Articles.append(OnePubMed_Articles)
# <ipython-input-9-8b13acba0f32>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   PubMed_Articles = PubMed_Articles.append(OnePubMed_Articles)

# %%
PubMed_Articles.head(10)
# Out:
#       PUMID                                                 TI  \
# 0  29790681  Multiple primary lung cancer: A literature rev...
# 1  27261907                       Epidemiology of Lung Cancer.
# 2  29635240                      Heterogeneity in Lung Cancer.
# 3  30955514                                       Lung Cancer.
# 4  26667338                      Lung Cancer in Never Smokers.
# 5  27607596                   Lung cancer in persons with HIV.
# 6  26667337                       Epidemiology of Lung Cancer.
# 7  24357736  Lung cancer screening: advantages, controversi...
# 8  17225705             Lung cancer: diagnosis and management.
# 9  27535388  Diagnosis and Molecular Classification of Lung...
#
#                                                   AB  Type
# 0  Nowadays, lung cancer is a leading cause of de...  Lung
# 1  Lung cancer has been transformed from a rare d...  Lung
# 2  Lung cancer diagnosis is a challenge since it ...  Lung
# ...

# %%
PubMed_Articles.shape
# Out:
# (9, 5)

# %%
PubMed_Articles['Type'].unique()
# Out:
# array(['Lung', 'Breast', 'Colorectal'], dtype=object)

# %%
OutputLoction = "/content/Output_PackSrc/pubmed-CancerType_Top1-4-set_Output.xlsx"
PubMed_Articles.to_excel(OutputLoction,index=False)
