# %%
import base64

def text_encoder(text):
    text_bytes = text.encode('utf-8')
    base64_bytes = base64.b64encode(text_bytes)
    return base64_bytes.decode('utf-8')

def text_decoder(encoded_text):
    base64_bytes = encoded_text.encode('utf-8')
    text_bytes = base64.b64decode(base64_bytes)
    return text_bytes.decode('utf-8')

# Example usage

original_text = input('Please input text: ')
encoded_text = text_encoder(original_text)
decoded_text = base64.b64decode(original_text)

print("Original text:", original_text)
print("Encoded text:", encoded_text)
print("Decoded text:", decoded_text)
# Out:
# Please input text: 3515WD7SP0bV5j34MN/fmg==
# Original text: 3515WD7SP0bV5j34MN/fmg==
# Encoded text: MzUxNVdEN1NQMGJWNWozNE1OL2ZtZz09
# Decoded text: b'\xdf\x9dyX>\xd2?F\xd5\xe6=\xf80\xdf\xdf\x9a'

# %%
import base64

# The encoded string
encoded_string = input('Please input encoded string: ')

# Decoding the string
decoded_string = base64.b64decode(encoded_string)

# Printing the decoded string
print(decoded_string)
# Out:
# Please input encoded string: MzUxNVdEN1NQMGJWNWozNE1OL2ZtZz09
# b'3515WD7SP0bV5j34MN/fmg=='
