# %%
import torch
import stable_diffusion

# Load the model
model = stable_diffusion.load_model("stable_diffusion_model.pth")

# Create a prompt
prompt = "A beautiful landscape painting of a mountain range"

# Generate an image
image = model.generate(prompt, temperature=0.5)

# Save the image
image.save("image.png")
