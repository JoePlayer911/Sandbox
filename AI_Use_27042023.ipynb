# %%
#Importing File
from pydrive.auth import GoogleAuth
from google.colab import drive
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

haze_file_id = '1uX0df_pgDDWPz6TtqsrTBo0vkJdaoM5b'

download = drive.CreateFile({'id': haze_file_id})
download.GetContentFile('haze.txt')

mrt_file_id = '1qJc0iFpc2DjGW5sufjYl9elV9gxLCQuq'

download = drive.CreateFile({'id': mrt_file_id})
download.GetContentFile('mrt.txt')

# %%
pip install --user -U nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)

# %%
import nltk
import re
from nltk.corpus import PlaintextCorpusReader

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
file_directory = '/content/'

# %%
filename_pattern = '.+\.txt'

# %%
my_corpus = PlaintextCorpusReader(file_directory, filename_pattern)

# %%
haze = my_corpus.words('haze.txt')

# %%
print(haze[0:30])
# Out:
# ['Singapore', 'can', 'expect', 'more', 'rain', 'and', 'less', 'haze', 'in', 'the', 'coming', 'weeks', 'with', 'the', 'south', '-', 'west', 'monsoon', 'season', 'transitioning', 'into', 'inter', '-', 'monsoon', 'conditions', '.', 'The', 'inter', '-', 'monsoon']

# %%
print(len(haze))
# Out:
# 117

# %%
fdist = nltk.FreqDist(haze)
print(fdist.most_common(10))
# Out:
# [('the', 11), ('and', 7), ('in', 5), ('.', 4), ('Singapore', 3), ('haze', 3), ('-', 3), ('monsoon', 3), ('season', 3), ('of', 3)]

# %%
haze_sents = my_corpus.sents('haze.txt')
print(haze_sents[0])
# Out:
# ['Singapore', 'can', 'expect', 'more', 'rain', 'and', 'less', 'haze', 'in', 'the', 'coming', 'weeks', 'with', 'the', 'south', '-', 'west', 'monsoon', 'season', 'transitioning', 'into', 'inter', '-', 'monsoon', 'conditions', '.']

# %%
haze_lower = [w.lower() for w in haze]
print(haze_lower[0:30])
# Out:
# ['singapore', 'can', 'expect', 'more', 'rain', 'and', 'less', 'haze', 'in', 'the', 'coming', 'weeks', 'with', 'the', 'south', '-', 'west', 'monsoon', 'season', 'transitioning', 'into', 'inter', '-', 'monsoon', 'conditions', '.', 'the', 'inter', '-', 'monsoon']

# %%
p = '[a-z]'
s1 = 'abc'
s2 = '123'

if re.search(p,s1):
  print('match')
else:
  print('not match')
# Out:
# match

# %%
haze_words_only = [w for w in haze_lower if re.search('^[a-z]+$',w)]
print(haze_words_only[0:30])
# Out:
# ['singapore', 'can', 'expect', 'more', 'rain', 'and', 'less', 'haze', 'in', 'the', 'coming', 'weeks', 'with', 'the', 'south', 'west', 'monsoon', 'season', 'transitioning', 'into', 'inter', 'monsoon', 'conditions', 'the', 'inter', 'monsoon', 'season', 'typically', 'lasts', 'from']

# %%
from nltk.corpus import stopwords
stop_list = stopwords.words('english')
haze_stopremoved = [w for w in haze_words_only if w not in stop_list]
print(haze_stopremoved)
# Out:
# ['singapore', 'expect', 'rain', 'less', 'haze', 'coming', 'weeks', 'south', 'west', 'monsoon', 'season', 'transitioning', 'inter', 'monsoon', 'conditions', 'inter', 'monsoon', 'season', 'typically', 'lasts', 'october', 'november', 'weather', 'period', 'characterised', 'rainfall', 'light', 'variable', 'winds', 'meteorological', 'service', 'singapore', 'said', 'monday', 'advisory', 'transition', 'signals', 'end', 'traditional', 'dry', 'season', 'region', 'likelihood', 'transboundary', 'haze', 'affecting', 'singapore', 'rest', 'year', 'low', 'increased', 'rainfall', 'help', 'alleviate', 'hotspot', 'haze', 'situation', 'sumatra', 'kalimantan', 'indonesia']
