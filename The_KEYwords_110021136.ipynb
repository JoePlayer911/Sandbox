# %%
# !pip install rake-nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.7/dist-packages (from rake-nltk) (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (7.1.2)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
# !pip3 install requests-html
# !import nltk; nltk.download('punkt')
# !import nltk; nltk.download('stopwords')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.5 MB/s
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting w3lib
#   Downloading w3lib-2.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests-html) (2.23.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html) (0.0.1)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (2022.9.24)
# Collecting urllib3<2.0.0,>=1.25.8
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 42.4 MB/s
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 48.1 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.64.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.13.0)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (4.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html) (4.6.3)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html) (4.9.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->requests-html) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests-html) (2.10)
# Collecting urllib3<2.0.0,>=1.25.8
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 60.6 MB/s
# Building wheels for collected packages: fake-useragent, parse
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=38fa7ce7a4b8358afbf9b750fbcc1d304949d65374579f20e5d6b54e6a5fc7a1
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=904c26b8ac7e45c003052db8b04dd4562eac0cb4b97885677a2a7eeb1222ffa2
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# Successfully built fake-useragent parse
# Installing collected packages: websockets, urllib3, pyee, cssselect, w3lib, pyquery, pyppeteer, parse, fake-useragent, requests-html
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed cssselect-1.1.0 fake-useragent-0.1.11 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 urllib3-1.25.11 w3lib-2.0.1 websockets-10.3

# %%
from requests_html import HTMLSession
from rake_nltk import Rake
import nltk; nltk.download('punkt')
import nltk; nltk.download('stopwords')

count = 0
def extract_text():
    s = HTMLSession()
    url = 'https://gutenberg.ca/ebooks/hemingwaye-oldmanandthesea/hemingwaye-oldmanandthesea-00-t.txt'
    response = s.get(url)
    return response.html.find('html', first=True).text


r = Rake()
r.extract_keywords_from_text(extract_text())
for rating, keyword in r.get_ranked_phrases_with_scores():
    if rating > 5:
      if count < 150:
        count = count +1
        print(keyword)
      else:
        break
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 21 may 2012 project gutenberg canada ebook
# 21 may 2012 date last updated
# white cumulus built like friendly piles
# blessed art thou among women
# old man saw flying fish spurt
# project gutenberg canada ebook
# still fishing correctly though faster
# america _all rights reserved
# laid full length across two planks
# old man could hardly breathe
# long deadly purple filaments trailing
# _un espuela de hueso_
# two deepest lines like plummets
# different display devices ),
# purple pectoral fins set wide
# _qu � va_ ,"
# _qu � va_ ,"
# _books by_ ernest hemingway
# projecting green sticks dip sharply
# night two porpoise came around
# sea ernest hemingway charles scribner
# whole bodies like eels
# caught big ones every day
# looked like high snow mountains
# tipped wide pectoral fins
# 1952 date first posted
# high dorsal fin knifing
# get four fresh ones ."
# thoughts aloud many times since
# great erect tail slicing
# africa winner take nothing death
# referees every four hours
# _agua mala_ came quickly
# played like young cats
# kicked like sand fleas
# two gray sucking fish
# sent two beers ."
# weigh ten pounds ."
# old man skinned one side
# good luck old man ."
# old man rode gently
# old man could see pieces
# keep warm old man ,"
# skiff would swing broadside
# shoulders moving steadily toward whatever
# native boats come riding
# paper napkin wrapped around
# two fresh small tunas
# hands well old man ."
# beautifully formed tails ."
# small delicate dark terns
# great long white spine
# really resting except comparatively
# young boys sleep late
# big shark sinking slowly
# prove us wrong ."
# two hundred fathoms high
# war floating close beside
# lost two hundred fathoms
# local people would steal
# old man said happily
# old man looked ahead
# big mako shark built
# new york 1952 copyright
# odds would change back
# bones two hours later
# much good counsel ,"
# blue dorsal fin cut
# great dimaggio fishing ,"
# gray blue hills behind
# wide lavender stripes showing
# line slanting slowly upward
# old man said aloud
# old man said aloud
# old man said aloud
# old man said aloud
# old man said aloud
# old man said aloud
# old man said aloud
# worn coral rock road
# arms men without women
# strange old man ,"
# strange old man ."
# old man could hear
# dark red meat longitudinally
# old man could feel
# old man could feel
# two sharks closed together
# brown fins coming along
# seven days without fish
# old man looked carefully
# old man felt faint
# sleep old man ?"
# always borrow two dollars
# sailing together lashed side
# old man said getting
# blood mushed hands driving
# two flying fish inside
# two flying fish inside
# old man could see
# old man could see
# old man could see
# old man could see
# old man could see
# old man could see
# five years old ."
# long black wings circling
# two oars together across
# _agua mala_ ,"
# live outside canada
# took another full piece
# sting ray stung
# please check gutenberg
# ernest hemingway printed
# canadian public domain
# boat moved ahead slowly
# everything kills everything else
# old man always thought
# makes everything wrong ."
# old man let go
# truly big fish ?"
# hook something truly big
# shark closed fast astern
# old man felt nothing
# great dimaggio would stay
# somewhat less intolerable
# fifteen hundred pounds
# caught three good fish
# one longer day ?"
# sometimes someone would speak
# absolutely without caution
# stiff set wings made
# old man unhooked
# old man stabbed
# old man reversed
# old man realized
# old man pinched
# old man nodded
# old man agreed
# first went together ."
# great brown mountains
# made another turn around
# virgen de cobre
# sturdy fibered _guano_
# heavy steady sea outside
# much luck yet ."
# feel confident today ."
# withheld great favours
# seen many great fish
# could go without sleeping
